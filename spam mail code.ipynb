# %% [markdown]
# # Shubankar Karthik G B

# %% [markdown]
# ### OIBSIP Task 4 Spam Mail Detection

# %% [markdown]
# ##### IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#DATASET
raw_mail_data = pd.read_csv('spamm_oibsip.csv',encoding=('ISO-8859-1'),low_memory=False)
print(raw_mail_data)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
index_to_drop = [2,3,4]

# %%
raw_mail_data.drop(raw_mail_data.columns[index_to_drop], axis=1, inplace=True)

# %%
print(raw_mail_data)
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#replace null values with null string
mail_data = raw_mail_data.where((pd.notnull(raw_mail_data)),'')

#print 1st 5 rows
mail_data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#checking no. of rows and columns in this dataset

mail_data.shape
# Out:
# (5572, 2)

# %%
#labelling spam mails as 0 and ham as 1

mail_data.loc[mail_data['v1']=='spam','Category',] = 0
mail_data.loc[mail_data['v1']=='ham','Category',] = 1

#seperating data as texts and labels

x = mail_data['v2']

y = mail_data['v1']

# %%
print(x)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: v2, Length: 5572, dtype: object

# %%
print(y)
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: v1, Length: 5572, dtype: object

# %%
mail_data = mail_data.sample(frac=1)
mail_data
# Out:
#         v1                                                 v2  Category
# 3406   ham  Beautiful Truth against Gravity.. Read careful...       1.0
# 2988  spam  No 1 POLYPHONIC tone 4 ur mob every week! Just...       0.0
# 62     ham                          Its a part of checking IQ       1.0
# 2774   ham     Dude u knw also telugu..thts gud..k, gud nyt..       1.0
# 4205   ham                             Get the door, I'm here       1.0
# ...    ...                                                ...       ...
# 4347   ham  You give us back my id proof and  &lt;#&gt;  r...       1.0
# 2331   ham                                 At home by the way       1.0
# 645    ham  Watching cartoon, listening music &amp; at eve...       1.0
# 403    ham   None of that's happening til you get here though       1.0
# 1414   ham  So wats ur opinion abt him and how abt is char...       1.0
#
# [5572 rows x 3 columns]

# %%
#splitting data into training data and test data

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %%
#FEATURE EXTRACTION
#transform text data to feature vectors thats used as input to logistic regression
feature_extraction = TfidfVectorizer(min_df=1, stop_words='english', lowercase=True)
x_train_features = feature_extraction.fit_transform(x_train)
x_test_features = feature_extraction.transform(x_test)

# %%
print(x_train_features)
# Out:
#   (0, 741)	0.3219352588930141
#   (0, 3979)	0.2410582143632299
#   (0, 4296)	0.3891385935794867
#   (0, 6599)	0.20296878731699391
#   (0, 3386)	0.3219352588930141
#   (0, 2122)	0.38613577623520473
#   (0, 3136)	0.440116181574609
#   (0, 3262)	0.25877035357606315
#   (0, 3380)	0.21807195185332803
#   (0, 4513)	0.2909649098524696
#   (1, 4061)	0.380431198316959
#   (1, 6872)	0.4306015894277422
#   (1, 6417)	0.4769136859540388
#   (1, 6442)	0.5652509076654626
#   (1, 7443)	0.35056971070320353
#   (2, 933)	0.4917598465723273
#   (2, 2109)	0.42972812260098503
#   (2, 3917)	0.40088501350982736
#   (2, 2226)	0.413484525934624
#   (2, 5825)	0.4917598465723273
#   (3, 6140)	0.4903863168693604
#   (3, 1599)	0.5927091854194291
#   (3, 1842)	0.3708680641487708
#   (3, 7453)	0.5202633571003087
#   (4, 2531)	0.7419319091456392
#   :	:
#   (4452, 2122)	0.31002103760284144
#   (4453, 999)	0.6760129013031282
#   (4453, 7273)	0.5787739591782677
#   (4453, 1762)	0.45610005640082985
# ...

# %% [markdown]
# # Training Model
# ### Logisitic Regression

# %%
model = LogisticRegression()

# %%
model.fit(x_train_features,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Evaluation of trained model
# ### Prediction on training

# %%
prediction_on_trainingdata = model.predict(x_train_features)
accuracy_on_trainingdata = accuracy_score(y_train,prediction_on_trainingdata)

# %%
print('Accuracy on training data', accuracy_on_trainingdata)
# Out:
# Accuracy on training data 0.9661207089970832

# %% [markdown]
# # Prediction on test data

# %%
prediction_on_testdata = model.predict(x_test_features)
accuracy_on_testdata = accuracy_score(y_test,prediction_on_testdata)
print('Accuracy score on test data', accuracy_on_testdata)
# Out:
# Accuracy score on test data 0.9623318385650225

# %%
#build predicitng system 

input_mail = ["SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info"]

input_data_features = feature_extraction.transform(input_mail)


#making prediction
prediction = model.predict(input_data_features)
print(prediction)

if (prediction[0] == 1):
    print("Ham mail")
else:
    print("spam mail")
# Out:
# ['spam']
# spam mail
